# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# p_array = [1,2,3]
# q_array = [1,2,3]

dt = 1 #in minute
t_array = np.linspace(0, 24, 24*60) #in hours

C = 100

plt.figure(1)
i = 1

alpha_array = [0.5] #alpha unit is per hours
# for p in p_array:
#     alpha_array = [p]#,q*N/C, (p + q*N/C)]
for alpha in alpha_array:
    N = 1
    x = []
    y = []
    y1 = []
    y1.append(0)
    y.append(N)
    x.append(t_array[0])
    flag = 0

    for t in range(1,len(t_array)):
        y1.append(alpha*(C - N)*1/60)
        N = N + alpha*(C - N)*1/60
        y.append(N)
        x.append(t_array[t])
        if(N>999 and flag == 0):
            flag = 1
            t_sat = t_array[t]
        
    
    plt.plot(x,y,label = 'numerical')
    plt.plot(x,y1,label = 'dN/dt') 
    
    #plt.plot(t_array,C - (C - 1)*(np.exp(-alpha*t_array)),label = 'analytical')
#     i = i+1
plt.xlabel('Time in hours')
plt.ylabel('Percentage that adopted')
plt.title('Market share of the product with time')
plt.legend()
plt.grid()
plt.show()
plt.savefig('trivial.png')

# %%
# %matplotlib qt
# p_array = [1,2,3]
# q_array = [1,2,3]

dt = 1 #in minute
t_array = np.linspace(0, 24*3, 24*60*3) #in hours

C = 10000

plt.figure(1)
i = 1

p_array = [0.018] #alpha unit is per hours
N_array = [1]
q_array = [150] #alpha unit is per hours

# for p in p_array:
#     alpha_array = [p]#,q*N/C, (p + q*N/C)]
for i in range(3):
    for p in p_array:
        for q in q_array:
            for n in N_array:
                N = n
                x = []
                y = []
                y.append((N/C)*100)
                x.append(t_array[0])
                flag = 0

                for t in range(1,len(t_array)):
                    if(i==2):
                        value = p + q*(N/C)
                    elif(i==1):
                        value = q*(N/C)
                    else:
                        value = p

                    N = N + value*(C - N)*1/60
                    y.append((N/C)*100)
                    x.append(t_array[t])
                    if((N/C)>0.9999 and flag == 0):
                        flag = 1
                        t_sat = t_array[t]


        #         if(flag==1):
        #             plt.plot(x,y,label = 'Innitial users: '+ str(n))
        #             plt.axvline(t_sat, linestyle='dashed',color = 'black')
        #         else:
                plt.plot(x,y,label ='p: '+ str(p) + ' n: ' + str(n) + ' q: ' + str(q))
    
#     plt.plot(t_array,C - (C - 1)*(np.exp(-alpha*t_array)),label = 'analytical')
#     i = i+1
plt.xlabel('Time in hours')
plt.ylabel('Percentage that adopted')
plt.title('Market share of the product with time')
plt.legend()
plt.grid()
plt.show()
plt.savefig('q_compare.png')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-428db06e6fa0> in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'qt')
#       2 # p_array = [1,2,3]
#       3 # q_array = [1,2,3]
#       4
#       5 dt = 1 #in minute
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2312                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2313             with self.builtin_trap:
# -> 2314                 result = fn(*args, **kwargs)
#    2315             return result
#    2316
#
# </usr/local/lib/python3.7/dist-packages/decorator.py:decorator-gen-108> in matplotlib(self, line)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
# ...

# %%
t = np.linspace(0, 100, 10000)
k1 = 3
k2 = 6
y = (12/k2)*(1 - (1/(k2-k1))*(k2*np.exp(-k1*t) - k1*np.exp(-k2*t)))
plt.figure(1)
plt.plot(t, y, label='2')

x = (12/k1)*(1 - np.exp(-k1*t))
plt.plot(t, x, label='1')
k1 = 0.2
k2=0.1
y = (10*k1/(k1-k2))*(np.exp(-k2*t) - np.exp(-k1*t))
plt.plot(t, y, label='no inflow 2')
k1= 0.2
x = 10*np.exp(-k1*t)
plt.plot(t, x, label='no inflow 1')
plt.legend()
plt.figure(2)
k=[10, 20]
r=[2, 10]
x0 = 1
for k in k:
    r=[2,10]
    for r in r:
        print(r, k)
        x = k*x0/(x0 + (k - x0)*np.exp(-r*t/k))
        plt.plot(t, x, label='k:' + str(k) + ' r:' + str(r))
        plt.legend()
# Out:
# 2 10
# 10 10
# 2 20
# 10 20
